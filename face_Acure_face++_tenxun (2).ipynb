# %% [markdown]
# # 使用三种API开放平台实现人脸识别

# %% [markdown]
# * 产品设计：在某些活动里使用人脸识别，当天已购票的人可以通过人脸识别重复多次进入会场。
# * [示例图片1 多人](https://c-ssl.duitang.com/uploads/item/202003/05/20200305113817_bplom.thumb.1000_0.jpg)
# * [示例图片2 单人](https://c-ssl.duitang.com/uploads/item/202004/07/20200407001503_ryede.thumb.1000_0.jpg)
# * [示例图片3 多人](https://c-ssl.duitang.com/uploads/item/202003/13/20200313082810_jobwv.thumb.1000_0.jpg)
# * [示例图片4 多人](https://c-ssl.duitang.com/uploads/item/201808/20/20180820014258_MwjeV.jpeg)

# %% [markdown]
# ## Azure

# %%
# 多人
import requests
import json
import pandas as pd

KEY = 'f701f8dd6fc1483fb8aed386a75b9b8e'  # Replace with a valid Subscription Key here.
BASE_URL = 'https://eastasia.api.cognitive.microsoft.com/face/v1.0/detect' 

# 沿用API的示范代碼，{subscription key}用KEY代入
HEADERS = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '{}'.format(KEY),
}

img_url = 'https://c-ssl.duitang.com/uploads/item/202003/05/20200305113817_bplom.thumb.1000_0.jpg'

data = {
    'url': '{}'.format(img_url),
}
payload = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'flase',
    'returnFaceAttributes': '{}'.format('age,gender,emotion'), 
}
r = requests.post(BASE_URL, data=json.dumps(data), params=payload, headers=HEADERS)

results = r.json()
df = pd.json_normalize(results)
df = df.set_index("faceId")
df = df.iloc[:,4:]
df
# Out:
#                                      faceAttributes.gender  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                  male
# 59105f09-8358-4590-8bc8-d3d91c75167e                  male
#
#                                       faceAttributes.age  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                19.0
# 59105f09-8358-4590-8bc8-d3d91c75167e                23.0
#
#                                       faceAttributes.emotion.anger  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                           0.0
# 59105f09-8358-4590-8bc8-d3d91c75167e                           0.0
#
#                                       faceAttributes.emotion.contempt  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                              0.0
# 59105f09-8358-4590-8bc8-d3d91c75167e                              0.0
#
#                                       faceAttributes.emotion.disgust  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                             0.0
# 59105f09-8358-4590-8bc8-d3d91c75167e                             0.0
#
#                                       faceAttributes.emotion.fear  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                          0.0
# 59105f09-8358-4590-8bc8-d3d91c75167e                          0.0
#
#                                       faceAttributes.emotion.happiness  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                             0.000
# 59105f09-8358-4590-8bc8-d3d91c75167e                             0.014
#
#                                       faceAttributes.emotion.neutral  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                           0.999
# 59105f09-8358-4590-8bc8-d3d91c75167e                           0.000
#
#                                       faceAttributes.emotion.sadness  \
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                           0.001
# 59105f09-8358-4590-8bc8-d3d91c75167e                           0.000
#
#                                       faceAttributes.emotion.surprise
# faceId
# cb52e0c4-1c39-420f-997e-e79161e5f70f                            0.000
# 59105f09-8358-4590-8bc8-d3d91c75167e                            0.986

# %%
# 单人
import requests
import json
import pandas as pd

KEY = 'f701f8dd6fc1483fb8aed386a75b9b8e'  # Replace with a valid Subscription Key here.
BASE_URL = 'https://eastasia.api.cognitive.microsoft.com/face/v1.0/detect' 

# 沿用API的示范代碼，{subscription key}用KEY代入
HEADERS = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '{}'.format(KEY),
}

img_url = 'https://c-ssl.duitang.com/uploads/item/202004/07/20200407001503_ryede.thumb.1000_0.jpg'

data = {
    'url': '{}'.format(img_url),
}
payload = {
    'returnFaceId': 'true',
    'returnFaceLandmarks': 'flase',
    'returnFaceAttributes': '{}'.format('age,gender,emotion'), 
}
r = requests.post(BASE_URL, data=json.dumps(data), params=payload, headers=HEADERS)

results = r.json()
df = pd.json_normalize(results)
df = df.set_index("faceId")
df = df.iloc[:,4:]
df
# Out:
#                                      faceAttributes.gender  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                  male
#
#                                       faceAttributes.age  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                19.0
#
#                                       faceAttributes.emotion.anger  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                           0.0
#
#                                       faceAttributes.emotion.contempt  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                              0.0
#
#                                       faceAttributes.emotion.disgust  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                             0.0
#
#                                       faceAttributes.emotion.fear  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                          0.0
#
#                                       faceAttributes.emotion.happiness  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                               0.0
#
#                                       faceAttributes.emotion.neutral  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                           0.995
#
#                                       faceAttributes.emotion.sadness  \
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                             0.0
#
#                                       faceAttributes.emotion.surprise
# faceId
# 55617006-5643-4f7e-aa18-0638eec997d1                            0.005

# %% [markdown]
# ## Face++

# %%
# 多人
import requests
import pandas as pd

api_secret = "GOIWWYgByZ_odq7kgchowa6nCZzNKVMU"
api_key = 'D-09_qb6yShR-K3ydXgs0ajfEf1SZhcX'  # Replace with a valid Subscription Key here.

BASE_URL = 'https://api-cn.faceplusplus.com/facepp/v3/detect' 
img_url = 'https://c-ssl.duitang.com/uploads/item/201808/20/20180820014258_MwjeV.jpeg'

headers = {
    'Content-Type': 'application/json',
}

payload = {
    "image_url":img_url,
    'api_key': api_key,
    'api_secret': api_secret,
    'return_attributes':'gender,age,smiling,emotion', 
}

r = requests.post(BASE_URL, params=payload, headers=headers)
r.status_code
r.json()
results = r.json()
results

face_pd = pd.json_normalize(results,record_path='faces')
face_pd
# Out:
#                          face_token  face_rectangle.top  face_rectangle.left  \
# 0  e3e7f97e8897767eb8d217ddecc1c822                 609                 1196
# 1  cc490051d873ae27afead16239386b59                 634                  165
# 2  d90c088c664aa2649094f2b1fc4ee482                 698                  564
# 3  e1104f08dc15779715c2a64897ef3efc                 416                  756
# 4  02b4dd2b668152c948be2cfc9e83933f                 441                  949
# 5  24989d6a3056f76cfd37773383cae285                 331                  561
# 6  a95f4e17ed32596f40b5a57c573ae039                 146                  460
# 7  19c70c8d78cb5e23586a19deef327e48                 249                  847
#
#    face_rectangle.width  face_rectangle.height attributes.gender.value  \
# 0                   241                    241                    Male
# 1                   201                    201                    Male
# 2                   150                    150                  Female
# 3                   127                    127                    Male
# 4                   121                    121                    Male
# 5                   110                    110                     NaN
# 6                   104                    104                     NaN
# 7                    98                     98                     NaN
#
#    attributes.age.value  attributes.smile.value  attributes.smile.threshold  \
# 0                  22.0                   0.017                        50.0
# 1                  22.0                   0.059                        50.0
# 2                  23.0                 100.000                        50.0
# 3                  20.0                   7.853                        50.0
# 4                  22.0                  85.131                        50.0
# 5                   NaN                     NaN                         NaN
# 6                   NaN                     NaN                         NaN
# 7                   NaN                     NaN                         NaN
#
#    attributes.emotion.anger  attributes.emotion.disgust  \
# 0                     0.003                       0.002
# 1                     0.001                       0.022
# 2                     0.000                       0.000
# 3                     0.413                       0.039
# 4                     0.001                       0.060
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
#
#    attributes.emotion.fear  attributes.emotion.happiness  \
# 0                    0.010                         0.007
# 1                    0.001                         0.179
# 2                    0.000                        99.999
# 3                    0.039                        47.033
# 4                    0.002                         3.684
# 5                      NaN                           NaN
# 6                      NaN                           NaN
# 7                      NaN                           NaN
#
#    attributes.emotion.neutral  attributes.emotion.sadness  \
# 0                      99.953                       0.024
# 1                      99.795                       0.001
# 2                       0.000                       0.000
# 3                      51.976                       0.459
# 4                      95.519                       0.732
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
#
#    attributes.emotion.surprise
# 0                        0.001
# 1                        0.002
# 2                        0.000
# 3                        0.039
# 4                        0.001
# 5                          NaN
# 6                          NaN
# 7                          NaN

# %% [markdown]
# ## 腾讯AI

# %%
import hashlib  
import time  
import random  
import string
import requests  
import base64  
import requests

import numpy as np
from urllib.parse import urlencode
import json #用于post后得到的字符串到字典的转换

app_id = '2131725665' 
app_key = 'OlsChRvRR5tCUgcd'

'''
        腾讯openai鉴权签名计算步骤：（摘抄自官网）
            用于计算签名的参数在不同接口之间会有差异，但算法过程固定如下4个步骤。
        1 将<key, value>请求参数对按key进行字典升序排序，得到有序的参数对列表N
        2 将列表N中的参数对按URL键值对的格式拼接成字符串，得到字符串T（如：key1=value1&key2=value2），URL键值拼接过程value部分需要URL编码，URL编码算法用大写字母，例如%E8，而不是小写%e8
        3 将应用密钥以app_key为键名，组成URL键值拼接到字符串T末尾，得到字符串S（如：key1=value1&key2=value2&app_key=密钥)
        4 对字符串S进行MD5运算，将得到的MD5值所有字符转换成大写，得到接口请求签名
'''

def face_check(img_data):
    """
    人脸识别demo
    :param img_data: 二进制的图片数据
    :return:
    """

    data = base64.b64encode(img_data)

    image = data.decode()

    imageType = "BASE64"
    
def get_params(img):                         #鉴权计算并返回请求参数
    #请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效
    time_stamp=str(int(time.time())) 
    #请求随机字符串，用于保证签名不可预测,16代表16位
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 16))

    params = {'app_id':app_id,                #请求包，需要根据不同的任务修改，基本相同
              'image':img,                    #文字类的任务可能是‘text’，由主函数传递进来
              'mode':'0' ,                    #身份证件类可能是'card_type'
              'time_stamp':time_stamp,        #时间戳，都一样
              'nonce_str':nonce_str,          #随机字符串，都一样
              #'sign':''                      #签名不参与鉴权计算，只是列出来示意
             }

    sort_dict= sorted(params.items(), key=lambda item:item[0], reverse = False)  #字典排序
    sort_dict.append(('app_key',app_key))   #尾部添加appkey
    rawtext= urlencode(sort_dict).encode()  #urlencod编码
    sha = hashlib.md5()    
    sha.update(rawtext)
    md5text= sha.hexdigest().upper()        #MD5加密计算
    params['sign']=md5text                  #将签名赋值到sign
    return  params                          #返回请求包

with open(r"C:\Users\ASUS\prem.jpg","rb")as f:
    base64_data = base64.b64encode(f.read())
    
params = get_params(base64_data)

url = "https://api.ai.qq.com/fcgi-bin/face/face_detectface"
res = requests.post(url,params).json()
res
# Out:
# {'ret': 0,
#  'msg': 'ok',
#  'data': {'image_width': 944,
#   'image_height': 1893,
#   'face_list': [{'face_id': '3589783860885369005',
#     'x': 588,
#     'y': 666,
#     'width': 292,
#     'height': 292,
#     'gender': 99,
#     'age': 24,
#     'expression': 0,
#     'beauty': 77,
#     'glass': 0,
#     'pitch': 4,
#     'yaw': 9,
#     'roll': -3,
#     'face_shape': {'face_profile': [{'x': 614, 'y': 754},
#       {'x': 612, 'y': 780},
#       {'x': 613, 'y': 805},
#       {'x': 617, 'y': 831},
#       {'x': 622, 'y': 856},
#       {'x': 631, 'y': 880},
#       {'x': 644, 'y': 902},
#       {'x': 660, 'y': 922},
#       {'x': 678, 'y': 940},
#       {'x': 700, 'y': 953},
#       {'x': 725, 'y': 957},
#       {'x': 748, 'y': 952},
#       {'x': 768, 'y': 938},
#       {'x': 786, 'y': 921},
#       {'x': 801, 'y': 902},
#       {'x': 814, 'y': 881},
#       {'x': 824, 'y': 859},
#       {'x': 832, 'y': 836},
#       {'x': 837, 'y': 813},
#       {'x': 840, 'y': 788},
#       {'x': 841, 'y': 767}],
#      'left_eye': [{'x': 659, 'y': 758},
#       {'x': 669, 'y': 763},
#       {'x': 680, 'y': 766},
#       {'x': 691, 'y': 766},
#       {'x': 702, 'y': 764},
#       {'x': 694, 'y': 755},
#       {'x': 682, 'y': 751},
#       {'x': 670, 'y': 752}],
#      'right_eye': [{'x': 808, 'y': 764},
#       {'x': 798, 'y': 769},
#       {'x': 788, 'y': 771},
#       {'x': 777, 'y': 770},
#       {'x': 767, 'y': 767},
#       {'x': 775, 'y': 759},
#       {'x': 786, 'y': 756},
#       {'x': 798, 'y': 758}],
#      'left_eyebrow': [{'x': 643, 'y': 731},
#       {'x': 661, 'y': 730},
#       {'x': 679, 'y': 731},
#       {'x': 697, 'y': 734},
#       {'x': 714, 'y': 735},
#       {'x': 699, 'y': 722},
#       {'x': 680, 'y': 718},
#       {'x': 659, 'y': 718}],
#      'right_eyebrow': [{'x': 833, 'y': 738},
#       {'x': 817, 'y': 737},
#       {'x': 800, 'y': 737},
#       {'x': 784, 'y': 737},
#       {'x': 768, 'y': 737},
#       {'x': 783, 'y': 725},
#       {'x': 802, 'y': 722},
#       {'x': 821, 'y': 724}],
#      'mouth': [{'x': 687, 'y': 887},
#       {'x': 699, 'y': 898},
#       {'x': 713, 'y': 906},
#       {'x': 729, 'y': 909},
#       {'x': 743, 'y': 907},
#       {'x': 755, 'y': 901},
#       {'x': 764, 'y': 891},
#       {'x': 756, 'y': 881},
#       {'x': 745, 'y': 874},
#       {'x': 733, 'y': 876},
#       {'x': 722, 'y': 872},
#       {'x': 704, 'y': 878},
#       {'x': 702, 'y': 888},
#       {'x': 717, 'y': 889},
#       {'x': 731, 'y': 891},
#       {'x': 742, 'y': 890},
#       {'x': 753, 'y': 891},
#       {'x': 753, 'y': 889},
#       {'x': 743, 'y': 888},
#       {'x': 732, 'y': 888},
#       {'x': 717, 'y': 887},
#       {'x': 702, 'y': 886}],
#      'nose': [{'x': 741, 'y': 826},
#       {'x': 737, 'y': 768},
#       {'x': 729, 'y': 784},
#       {'x': 720, 'y': 800},
#       {'x': 712, 'y': 816},
#       {'x': 700, 'y': 835},
#       {'x': 720, 'y': 845},
#       {'x': 737, 'y': 849},
#       {'x': 752, 'y': 847},
#       {'x': 767, 'y': 838},
#       {'x': 760, 'y': 819},
#       {'x': 752, 'y': 802},
#       {'x': 745, 'y': 785}]}},
#    {'face_id': '3589783866892660899',
#     'x': 121,
#     'y': 674,
#     'width': 272,
#     'height': 272,
#     'gender': 95,
#     'age': 25,
#     'expression': 27,
#     'beauty': 83,
#     'glass': 0,
#     'pitch': 5,
#     'yaw': 3,
#     'roll': 1,
#     'face_shape': {'face_profile': [{'x': 145, 'y': 749},
#       {'x': 143, 'y': 775},
#       {'x': 143, 'y': 800},
#       {'x': 147, 'y': 826},
#       {'x': 153, 'y': 850},
#       {'x': 161, 'y': 874},
#       {'x': 173, 'y': 897},
#       {'x': 187, 'y': 918},
#       {'x': 204, 'y': 938},
#       {'x': 224, 'y': 952},
#       {'x': 249, 'y': 957},
#       {'x': 273, 'y': 950},
#       {'x': 291, 'y': 934},
#       {'x': 307, 'y': 915},
#       {'x': 321, 'y': 894},
#       {'x': 334, 'y': 873},
#       {'x': 344, 'y': 850},
#       {'x': 351, 'y': 826},
#       {'x': 356, 'y': 802},
#       {'x': 358, 'y': 777},
#       {'x': 358, 'y': 755}],
#      'left_eye': [{'x': 182, 'y': 754},
#       {'x': 191, 'y': 760},
#       {'x': 202, 'y': 762},
#       {'x': 213, 'y': 760},
#       {'x': 223, 'y': 756},
#       {'x': 216, 'y': 745},
#       {'x': 203, 'y': 740},
#       {'x': 190, 'y': 743}],
#      'right_eye': [{'x': 321, 'y': 751},
#       {'x': 313, 'y': 757},
#       {'x': 303, 'y': 760},
#       {'x': 292, 'y': 760},
#       {'x': 282, 'y': 757},
#       {'x': 289, 'y': 747},
#       {'x': 300, 'y': 742},
#       {'x': 312, 'y': 744}],
#      'left_eyebrow': [{'x': 170, 'y': 714},
#       {'x': 185, 'y': 714},
#       {'x': 201, 'y': 715},
#       {'x': 216, 'y': 718},
#       {'x': 231, 'y': 721},
#       {'x': 219, 'y': 707},
#       {'x': 202, 'y': 702},
#       {'x': 184, 'y': 702}],
#      'right_eyebrow': [{'x': 342, 'y': 726},
#       {'x': 325, 'y': 723},
#       {'x': 307, 'y': 722},
#       {'x': 290, 'y': 724},
#       {'x': 272, 'y': 726},
#       {'x': 287, 'y': 712},
#       {'x': 307, 'y': 708},
#       {'x': 327, 'y': 712}],
#      'mouth': [{'x': 209, 'y': 875},
#       {'x': 216, 'y': 894},
#       {'x': 229, 'y': 909},
#       {'x': 249, 'y': 914},
#       {'x': 268, 'y': 910},
#       {'x': 283, 'y': 896},
#       {'x': 290, 'y': 877},
#       {'x': 279, 'y': 862},
#       {'x': 262, 'y': 852},
#       {'x': 249, 'y': 855},
#       {'x': 236, 'y': 851},
#       {'x': 220, 'y': 860},
#       {'x': 221, 'y': 885},
#       {'x': 234, 'y': 893},
#       {'x': 249, 'y': 897},
#       {'x': 264, 'y': 894},
#       {'x': 278, 'y': 887},
#       {'x': 277, 'y': 871},
#       {'x': 263, 'y': 867},
#       {'x': 249, 'y': 865},
#       {'x': 235, 'y': 866},
#       {'x': 222, 'y': 869}],
#      'nose': [{'x': 253, 'y': 816},
#       {'x': 254, 'y': 759},
#       {'x': 246, 'y': 775},
#       {'x': 239, 'y': 790},
#       {'x': 232, 'y': 806},
#       {'x': 224, 'y': 822},
#       {'x': 238, 'y': 831},
#       {'x': 252, 'y': 834},
#       {'x': 265, 'y': 832},
#       {'x': 280, 'y': 825},
#       {'x': 274, 'y': 808},
#       {'x': 267, 'y': 791},
#       {'x': 260, 'y': 775}]}}]}}

# %% [markdown]
# ## 运用Face++分析人脸数据制作数据表格

# %%
results = r.json()
results
# Out:
# {'request_id': '1586575786,087926fc-edfd-4e42-926c-3312b010f67c',
#  'time_used': 738,
#  'faces': [{'face_token': 'e3e7f97e8897767eb8d217ddecc1c822',
#    'face_rectangle': {'top': 609, 'left': 1196, 'width': 241, 'height': 241},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 22},
#     'smile': {'value': 0.017, 'threshold': 50.0},
#     'emotion': {'anger': 0.003,
#      'disgust': 0.002,
#      'fear': 0.01,
#      'happiness': 0.007,
#      'neutral': 99.953,
#      'sadness': 0.024,
#      'surprise': 0.001}}},
#   {'face_token': 'cc490051d873ae27afead16239386b59',
#    'face_rectangle': {'top': 634, 'left': 165, 'width': 201, 'height': 201},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 22},
#     'smile': {'value': 0.059, 'threshold': 50.0},
#     'emotion': {'anger': 0.001,
#      'disgust': 0.022,
#      'fear': 0.001,
#      'happiness': 0.179,
#      'neutral': 99.795,
#      'sadness': 0.001,
#      'surprise': 0.002}}},
#   {'face_token': 'd90c088c664aa2649094f2b1fc4ee482',
#    'face_rectangle': {'top': 698, 'left': 564, 'width': 150, 'height': 150},
#    'attributes': {'gender': {'value': 'Female'},
#     'age': {'value': 23},
#     'smile': {'value': 100.0, 'threshold': 50.0},
#     'emotion': {'anger': 0.0,
#      'disgust': 0.0,
#      'fear': 0.0,
#      'happiness': 99.999,
#      'neutral': 0.0,
#      'sadness': 0.0,
#      'surprise': 0.0}}},
#   {'face_token': 'e1104f08dc15779715c2a64897ef3efc',
#    'face_rectangle': {'top': 416, 'left': 756, 'width': 127, 'height': 127},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 20},
#     'smile': {'value': 7.853, 'threshold': 50.0},
#     'emotion': {'anger': 0.413,
#      'disgust': 0.039,
#      'fear': 0.039,
#      'happiness': 47.033,
#      'neutral': 51.976,
#      'sadness': 0.459,
#      'surprise': 0.039}}},
#   {'face_token': '02b4dd2b668152c948be2cfc9e83933f',
#    'face_rectangle': {'top': 441, 'left': 949, 'width': 121, 'height': 121},
#    'attributes': {'gender': {'value': 'Male'},
#     'age': {'value': 22},
#     'smile': {'value': 85.131, 'threshold': 50.0},
#     'emotion': {'anger': 0.001,
#      'disgust': 0.06,
#      'fear': 0.002,
#      'happiness': 3.684,
#      'neutral': 95.519,
#      'sadness': 0.732,
#      'surprise': 0.001}}},
#   {'face_token': '24989d6a3056f76cfd37773383cae285',
#    'face_rectangle': {'top': 331, 'left': 561, 'width': 110, 'height': 110}},
#   {'face_token': 'a95f4e17ed32596f40b5a57c573ae039',
#    'face_rectangle': {'top': 146, 'left': 460, 'width': 104, 'height': 104}},
#   {'face_token': '19c70c8d78cb5e23586a19deef327e48',
#    'face_rectangle': {'top': 249, 'left': 847, 'width': 98, 'height': 98}}],
#  'image_id': 'ZqCj85fabX5HdWpfuKPxzA==',
#  'face_num': 8}

# %%
import pandas as pd
df = pd.json_normalize(results,record_path='faces')
df = df.rename (columns = {"attributes.gender.value":"性别",
                           "attributes.age.value":"年龄",
                           "attributes.smile.value":"笑容",
                           "attributes.smile.threshold":"是否有笑容",
                           "attributes.emotion.anger":"愤怒",
                           "attributes.emotion.disgust":"厌恶",
                           "attributes.emotion.fear":"恐惧",
                           "attributes.emotion.happiness":"高兴",
                           "attributes.emotion.neutral":"平静",
                           "attributes.emotion.sadness":"悲伤",
                           "attributes.emotion.surprise":"惊讶"})
df = df.set_index('face_token')
df = df.iloc[:,4:]
df.replace({"Male":"男",
            "Female":"女",})
# Out:
#                                    性别    年龄       笑容  是否有笑容     愤怒     厌恶  \
# face_token
# e3e7f97e8897767eb8d217ddecc1c822    男  22.0    0.017   50.0  0.003  0.002
# cc490051d873ae27afead16239386b59    男  22.0    0.059   50.0  0.001  0.022
# d90c088c664aa2649094f2b1fc4ee482    女  23.0  100.000   50.0  0.000  0.000
# e1104f08dc15779715c2a64897ef3efc    男  20.0    7.853   50.0  0.413  0.039
# 02b4dd2b668152c948be2cfc9e83933f    男  22.0   85.131   50.0  0.001  0.060
# 24989d6a3056f76cfd37773383cae285  NaN   NaN      NaN    NaN    NaN    NaN
# a95f4e17ed32596f40b5a57c573ae039  NaN   NaN      NaN    NaN    NaN    NaN
# 19c70c8d78cb5e23586a19deef327e48  NaN   NaN      NaN    NaN    NaN    NaN
#
#                                      恐惧      高兴      平静     悲伤     惊讶
# face_token
# e3e7f97e8897767eb8d217ddecc1c822  0.010   0.007  99.953  0.024  0.001
# cc490051d873ae27afead16239386b59  0.001   0.179  99.795  0.001  0.002
# d90c088c664aa2649094f2b1fc4ee482  0.000  99.999   0.000  0.000  0.000
# e1104f08dc15779715c2a64897ef3efc  0.039  47.033  51.976  0.459  0.039
# 02b4dd2b668152c948be2cfc9e83933f  0.002   3.684  95.519  0.732  0.001
# 24989d6a3056f76cfd37773383cae285    NaN     NaN     NaN    NaN    NaN
# a95f4e17ed32596f40b5a57c573ae039    NaN     NaN     NaN    NaN    NaN
# 19c70c8d78cb5e23586a19deef327e48    NaN     NaN     NaN    NaN    NaN

# %% [markdown]
# ### 三家不同的人脸识别api的不同之处
# * Azure：提供给大家：人脸识别、计算机视觉（图像识别）和情绪分析
# * Face++：检测图片中的人脸并标记出人脸坐标，支持同时识别多张人脸
# * 腾讯A：基于腾讯优图强大的面部分析技术，提供包括人脸检测与分析、五官定位、人脸搜索、人脸比对、人脸验证、人员查重、活体检测等多种功能
